# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
citibike_202012_data = pd.read_csv("JC-202012-citibike-tripdata.csv")
citibike_202012_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
citibike_202011_data = pd.read_csv("JC-202011-citibike-tripdata.csv")
citibike_202011_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           756  2020-11-01 00:11:32.6250  2020-11-01 00:24:09.5850
# 1           584  2020-11-01 00:14:20.4820  2020-11-01 00:24:04.7820
# 2           403  2020-11-01 00:22:55.8820  2020-11-01 00:29:39.0950
# 3           498  2020-11-01 00:41:37.4270  2020-11-01 00:49:55.7010
# 4           151  2020-11-01 00:53:21.2340  2020-11-01 00:55:52.8060
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3681           Grand St               40.715178
# 2              3203      Hamilton Park               40.727596
# 3              3268     Lafayette Park               40.713464
# 4              3185          City Hall               40.717733
#
#    start station longitude  end station id       end station name  \
# 0               -74.038914            3225  Baldwin at Montgomery
# ...

# %%
citibike_202010_data = pd.read_csv("JC-202010-citibike-tripdata.csv")
citibike_202009_data = pd.read_csv("JC-202009-citibike-tripdata.csv")
citibike_202008_data = pd.read_csv("JC-202008-citibike-tripdata.csv")
citibike_202007_data = pd.read_csv("JC-202007-citibike-tripdata.csv")
citibike_2020_end_data = pd.concat([citibike_202007_data, citibike_202008_data, citibike_202009_data, citibike_202010_data, citibike_202011_data, citibike_202012_data])

# %%
citibike_2020_end_data.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# 11689              3199       Newport Pkwy               40.728745
# 11690              3184        Paulus Hook               40.714145
# 11691              3195            Sip Ave               40.730897
# 11692              3681           Grand St               40.715178
# 11693              3267       Morris Canal               40.712419
#
#        start station longitude  end station id end station name  \
# ...

# %%
citibike_2020_end_data.to_csv("citibike_2020_end.csv", index=False)

# %%
citibike_2020_end_data.shape
# Out:
# (198835, 15)

# %%
citibike_202007_data.shape
# Out:
# (38680, 15)

# %%
citibike_202008_data.shape
# Out:
# (43267, 15)

# %%
citibike_202009_data.shape
# Out:
# (53833, 15)

# %%
citibike_202010_data.shape
# Out:
# (30086, 15)

# %%
citibike_202011_data.shape
# Out:
# (21275, 15)

# %%
citibike_202012_data.shape
# Out:
# (11694, 15)

# %%
citibike_2020_end_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
citibike_202012_data.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# 11689              3199       Newport Pkwy               40.728745
# 11690              3184        Paulus Hook               40.714145
# 11691              3195            Sip Ave               40.730897
# 11692              3681           Grand St               40.715178
# 11693              3267       Morris Canal               40.712419
#
#        start station longitude  end station id end station name  \
# ...

# %%
citibike_202006_data = pd.read_csv("JC-202006-citibike-tripdata.csv")
citibike_202005_data = pd.read_csv("JC-202005-citibike-tripdata.csv")
citibike_202004_data = pd.read_csv("JC-202004-citibike-tripdata.csv")
citibike_202003_data = pd.read_csv("JC-202003-citibike-tripdata.csv")
citibike_202002_data = pd.read_csv("JC-202002-citibike-tripdata.csv")
citibike_202001_data = pd.read_csv("JC-202001-citibike-tripdata.csv")
citibike_2020_begin_data = pd.concat([citibike_202001_data, citibike_202002_data, citibike_202003_data, citibike_202004_data, citibike_202005_data, citibike_202006_data])

# %%
citibike_2020_begin_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
citibike_2020_begin_data.shape
# Out:
# (137967, 15)

# %%
citibike_2020_data = pd.concat([citibike_2020_begin_data, citibike_2020_end_data])
citibike_2020_data.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# 11689              3199       Newport Pkwy               40.728745
# 11690              3184        Paulus Hook               40.714145
# 11691              3195            Sip Ave               40.730897
# 11692              3681           Grand St               40.715178
# 11693              3267       Morris Canal               40.712419
#
#        start station longitude  end station id end station name  \
# ...

# %%
citibike_2020_data.shape
# Out:
# (336802, 15)

# %%
citibike_201901_data = pd.read_csv("JC-201901-citibike-tripdata.csv")
citibike_201902_data = pd.read_csv("JC-201902-citibike-tripdata.csv")
citibike_201903_data = pd.read_csv("JC-201903-citibike-tripdata.csv")
citibike_201904_data = pd.read_csv("JC-201904-citibike-tripdata.csv")
citibike_201905_data = pd.read_csv("JC-201905-citibike-tripdata.csv")
citibike_201906_data = pd.read_csv("JC-201906-citibike-tripdata.csv")
citibike_201907_data = pd.read_csv("JC-201907-citibike-tripdata.csv")
citibike_201908_data = pd.read_csv("JC-201908-citibike-tripdata.csv")
citibike_201909_data = pd.read_csv("JC-201909-citibike-tripdata.csv")
citibike_201910_data = pd.read_csv("JC-201910-citibike-tripdata.csv")
citibike_201911_data = pd.read_csv("JC-201911-citibike-tripdata.csv")
citibike_201912_data = pd.read_csv("JC-201912-citibike-tripdata.csv")
citibike_2019_data = pd.concat([citibike_201901_data, citibike_201902_data, citibike_201903_data, citibike_201904_data, citibike_201905_data, citibike_201906_data, citibike_201907_data, citibike_201908_data, citibike_201909_data, citibike_201910_data, citibike_201911_data, citibike_201912_data])
citibike_2019_data.shape
# Out:
# (404947, 15)

# %%
citibike_201801_data = pd.read_csv("JC-201801-citibike-tripdata.csv")
citibike_201802_data = pd.read_csv("JC-201802-citibike-tripdata.csv")
citibike_201803_data = pd.read_csv("JC-201803-citibike-tripdata.csv")
citibike_201804_data = pd.read_csv("JC-201804-citibike-tripdata.csv")
citibike_201805_data = pd.read_csv("JC-201805-citibike-tripdata.csv")
citibike_201806_data = pd.read_csv("JC-201806-citibike-tripdata.csv")
citibike_201807_data = pd.read_csv("JC-201807-citibike-tripdata.csv")
citibike_201808_data = pd.read_csv("JC-201808-citibike-tripdata.csv")
citibike_201809_data = pd.read_csv("JC-201809-citibike-tripdata.csv")
citibike_201810_data = pd.read_csv("JC-201810-citibike-tripdata.csv")
citibike_201811_data = pd.read_csv("JC-201811-citibike-tripdata.csv")
citibike_201812_data = pd.read_csv("JC-201812-citibike-tripdata.csv")
citibike_2018_data = pd.concat([citibike_201801_data, citibike_201802_data, citibike_201803_data, citibike_201804_data, citibike_201805_data, citibike_201806_data, citibike_201807_data, citibike_201808_data, citibike_201809_data, citibike_201910_data, citibike_201811_data, citibike_201812_data])
citibike_2018_data.shape
# Out:
# (357007, 15)

# %%
citibike_2018_data.head(20)
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1            550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2            510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3            354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4            250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# 5            613  2018-01-01 22:05:05.8740  2018-01-01 22:15:19.4190
# 6            290  2018-01-02 12:13:51.7940  2018-01-02 12:18:42.1070
# 7            381  2018-01-02 12:50:03.3430  2018-01-02 12:56:24.6440
# 8            318  2018-01-02 13:55:58.2430  2018-01-02 14:01:16.8810
# 9           1852  2018-01-02 16:55:29.6390  2018-01-02 17:26:22.3050
# 10           460  2018-01-02 17:01:50.5860  2018-01-02 17:09:31.4340
# 11           403  2018-01-02 17:05:12.2360  2018-01-02 17:11:55.2630
# 12           264  2018-01-02 17:05:12.6730  2018-01-02 17:09:37.4020
# ...

# %%
citibike_2018_data.tail(20)
# Out:
#        tripduration                 starttime                  stoptime  \
# 20185           668  2018-12-14 12:34:01.0310  2018-12-14 12:45:09.6550
# 20186           645  2018-12-15 13:31:59.3590  2018-12-15 13:42:45.2030
# 20187          1396  2018-12-15 16:28:38.1250  2018-12-15 16:51:54.9460
# 20188           649  2018-12-16 11:55:07.8820  2018-12-16 12:05:57.4260
# 20189           984  2018-12-17 06:26:18.2690  2018-12-17 06:42:42.9330
# 20190           687  2018-12-17 12:18:47.1320  2018-12-17 12:30:14.5090
# 20191           726  2018-12-17 17:38:45.4430  2018-12-17 17:50:52.4320
# 20192          1041  2018-12-18 06:21:57.7450  2018-12-18 06:39:19.7440
# 20193           654  2018-12-18 12:12:40.2980  2018-12-18 12:23:34.4020
# 20194          1015  2018-12-19 06:15:11.2330  2018-12-19 06:32:06.2450
# 20195           667  2018-12-19 11:39:50.4270  2018-12-19 11:50:58.2750
# 20196           687  2018-12-20 13:28:39.0590  2018-12-20 13:40:06.6410
# ...

# %%
citibike_201701_data = pd.read_csv("JC-201701-citibike-tripdata.csv")
citibike_201702_data = pd.read_csv("JC-201702-citibike-tripdata.csv")
citibike_201703_data = pd.read_csv("JC-201703-citibike-tripdata.csv")
citibike_201704_data = pd.read_csv("JC-201704-citibike-tripdata.csv")
citibike_201705_data = pd.read_csv("JC-201705-citibike-tripdata.csv")
citibike_201706_data = pd.read_csv("JC-201706-citibike-tripdata.csv")
citibike_201707_data = pd.read_csv("JC-201707-citibike-tripdata.csv")
citibike_201708_data = pd.read_csv("JC-201708-citibike-tripdata.csv")
citibike_201709_data = pd.read_csv("JC-201709-citibike-tripdata.csv")
citibike_201710_data = pd.read_csv("JC-201710-citibike-tripdata.csv")
citibike_201711_data = pd.read_csv("JC-201711-citibike-tripdata.csv")
citibike_201712_data = pd.read_csv("JC-201712-citibike-tripdata.csv")
citibike_2017_data = pd.concat([citibike_201701_data, citibike_201702_data, citibike_201703_data, citibike_201704_data, citibike_201705_data, citibike_201706_data, citibike_201707_data, citibike_201708_data, citibike_201709_data, citibike_201710_data, citibike_201711_data, citibike_201712_data])
citibike_2017_data.shape
# Out:
# (294928, 30)

# %%
citibike_201701_data.shape
# Out:
# (12926, 15)

# %%
citibike_201702_data.shape
# Out:
# (14026, 15)

# %%
citibike_201703_data.shape
# Out:
# (12201, 15)

# %%
citibike_201704_data.shape
# Out:
# (21186, 15)

# %%
citibike_201705_data.shape
# Out:
# (25966, 15)

# %%
citibike_201706_data.shape
# Out:
# (32060, 15)

# %%
citibike_201707_data.shape
# Out:
# (33573, 15)

# %%
citibike_201708_data.shape
# Out:
# (35472, 15)

# %%
citibike_201709_data.shape
# Out:
# (33119, 15)

# %%
citibike_201710_data.shape
# Out:
# (34919, 15)

# %%
citibike_201711_data.shape
# Out:
# (23582, 15)

# %%
citibike_201712_data.shape
# Out:
# (15898, 15)

# %%
citibike_2017_data.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0          148.0  2017-01-01 00:21:32  2017-01-01 00:24:01            3276.0
# 1         1283.0  2017-01-01 00:24:35  2017-01-01 00:45:58            3183.0
# 2          372.0  2017-01-01 00:38:19  2017-01-01 00:44:31            3183.0
# 3         1513.0  2017-01-01 00:38:37  2017-01-01 01:03:50            3194.0
# 4          639.0  2017-01-01 01:47:52  2017-01-01 01:58:31            3183.0
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  ...  \
# ...

# %%
citibike_2017_data.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender', 'tripduration', 'starttime', 'stoptime',
#        'start station id', 'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citibike_201712_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32              3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21              3187
# 2           175  2017-12-01 00:17:00  2017-12-01 00:19:55              3186
# 3           455  2017-12-01 00:50:22  2017-12-01 00:57:57              3194
# 4           670  2017-12-01 00:55:03  2017-12-01 01:06:13              3194
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    end station id      end station name  end station latitude  \
# ...

# %%
citibike_201801_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
citibike_201703_data.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1076  2017-03-01 00:03:02  2017-03-01 00:20:58              3275
# 1            978  2017-03-01 00:09:02  2017-03-01 00:25:20              3220
# 2           1789  2017-03-01 00:28:11  2017-03-01 00:58:00              3195
# 3            613  2017-03-01 00:52:30  2017-03-01 01:02:44              3194
# 4           2418  2017-03-01 00:54:40  2017-03-01 01:34:59              3199
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0     Columbus Drive               40.718355               -74.038914
# 1  5 Corners Library               40.734961               -74.059503
# 2            Sip Ave               40.730743               -74.063784
# 3    McGinley Square               40.725340               -74.067622
# 4       Newport Pkwy               40.728745               -74.032108
#
#    End Station ID      End Station Name  End Station Latitude  \
# ...

# %%
citibike_201701_data.rename(columns = {'Trip Duration':'tripduration', 'Start Time':'starttime', 'Stop Time':'stoptime', 'Start Station ID':'start station id',
       'Start Station Name':'start station name', 'Start Station Latitude':'start station latitude',
       'Start Station Longitude':'start station longitude', 'End Station ID':'end station id', 'End Station Name':'end station name',
       'End Station Latitude':'end station latitude', 'End Station Longitude':'end station longitude', 'Bike ID':'bikeid', 'User Type':'usertype',
       'Birth Year':'birth year', 'Gender':'gender'}, inplace=True)
citibike_201701_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1          1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2           372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3          1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4           639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id     end station name  end station latitude  \
# ...

# %%
citibike_201701_data.rename(columns = {'Trip Duration':'tripduration'})
citibike_201701_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1          1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2           372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3          1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4           639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id     end station name  end station latitude  \
# ...

# %%
citibike_201702_data.rename(columns = {'Trip Duration':'tripduration', 'Start Time':'starttime', 'Stop Time':'stoptime', 'Start Station ID':'start station id',
       'Start Station Name':'start station name', 'Start Station Latitude':'start station latitude',
       'Start Station Longitude':'start station longitude', 'End Station ID':'end station id', 'End Station Name':'end station name',
       'End Station Latitude':'end station latitude', 'End Station Longitude':'end station longitude', 'Bike ID':'bikeid', 'User Type':'usertype',
       'Birth Year':'birth year', 'Gender':'gender'}, inplace=True)
citibike_201702_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           435  2017-02-01 00:06:33  2017-02-01 00:13:49              3214
# 1           779  2017-02-01 01:02:21  2017-02-01 01:15:21              3194
# 2           145  2017-02-01 01:56:05  2017-02-01 01:58:30              3211
# 3           184  2017-02-01 04:38:42  2017-02-01 04:41:46              3276
# 4           197  2017-02-01 04:42:22  2017-02-01 04:45:39              3214
#
#   start station name  start station latitude  start station longitude  \
# 0   Essex Light Rail               40.712774               -74.036486
# 1    McGinley Square               40.725340               -74.067622
# 2         Newark Ave               40.721525               -74.046305
# 3   Marin Light Rail               40.714584               -74.042817
# 4   Essex Light Rail               40.712774               -74.036486
#
#    end station id      end station name  end station latitude  \
# ...

# %%
citibike_201703_data.rename(columns = {'Trip Duration':'tripduration', 'Start Time':'starttime', 'Stop Time':'stoptime', 'Start Station ID':'start station id',
       'Start Station Name':'start station name', 'Start Station Latitude':'start station latitude',
       'Start Station Longitude':'start station longitude', 'End Station ID':'end station id', 'End Station Name':'end station name',
       'End Station Latitude':'end station latitude', 'End Station Longitude':'end station longitude', 'Bike ID':'bikeid', 'User Type':'usertype',
       'Birth Year':'birth year', 'Gender':'gender'}, inplace=True)
citibike_201703_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1076  2017-03-01 00:03:02  2017-03-01 00:20:58              3275
# 1           978  2017-03-01 00:09:02  2017-03-01 00:25:20              3220
# 2          1789  2017-03-01 00:28:11  2017-03-01 00:58:00              3195
# 3           613  2017-03-01 00:52:30  2017-03-01 01:02:44              3194
# 4          2418  2017-03-01 00:54:40  2017-03-01 01:34:59              3199
#
#   start station name  start station latitude  start station longitude  \
# 0     Columbus Drive               40.718355               -74.038914
# 1  5 Corners Library               40.734961               -74.059503
# 2            Sip Ave               40.730743               -74.063784
# 3    McGinley Square               40.725340               -74.067622
# 4       Newport Pkwy               40.728745               -74.032108
#
#    end station id      end station name  end station latitude  \
# ...

# %%
citibike_2017_data = pd.concat([citibike_201701_data, citibike_201702_data, citibike_201703_data, citibike_201704_data, citibike_201705_data, citibike_201706_data, citibike_201707_data, citibike_201708_data, citibike_201709_data, citibike_201710_data, citibike_201711_data, citibike_201712_data])
citibike_2017_data.shape
# Out:
# (294928, 15)

# %%
citibike_2017_data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citibike_2020_data.to_csv("citibike_2020.csv", index=False)

# %%
citibike_2019_data.to_csv("citibike_2019.csv", index=False)

# %%
citibike_2018_data.to_csv("citibike_2018.csv", index=False)

# %%
citibike_2017_data.to_csv("citibike_2017.csv", index=False)

# %%
citibike_2018_data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citibike_2019_data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citibike_2020_data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
citibike_2017_data['birth year'].astype
# Out:
# <bound method NDFrame.astype of 0        1983.0
# 1        1978.0
# 2        1989.0
# 3        1961.0
# 4        1993.0
#           ...
# 15893    1987.0
# 15894    1994.0
# 15895    1957.0
# 15896    1964.0
# 15897    1979.0
# Name: birth year, Length: 294928, dtype: float64>

# %%
citibike_2017_data.dropna(inplace=True)

# %%
citibike_2017_data['birth year'] = citibike_2017_data['birth year'].astype('int64', errors='raise')

# %%
citibike_2017_data.shape
# Out:
# (275196, 15)

# %%
citibike_2017_data['birth year'] = citibike_2017_data['birth year'].astype('int64', errors='raise')

# %%
citibike_2017_data.shape
# Out:
# (275196, 15)

# %%
citibike_2017_data['birth year'].astype
# Out:
# <bound method NDFrame.astype of 0        1983
# 1        1978
# 2        1989
# 3        1961
# 4        1993
#          ...
# 15893    1987
# 15894    1994
# 15895    1957
# 15896    1964
# 15897    1979
# Name: birth year, Length: 275196, dtype: int64>

# %%
citibike_2017_data.to_csv("citibike_2017.csv", index=False)

# %%
citibike_2017_data.shape
# Out:
# (275196, 15)

# %%
citibike_2017_data['starttime'].astype
# Out:
# <bound method NDFrame.astype of 0        2017-01-01 00:21:32.0000
# 1        2017-01-01 00:24:35.0000
# 2        2017-01-01 00:38:19.0000
# 3        2017-01-01 00:38:37.0000
# 4        2017-01-01 01:47:52.0000
#                    ...
# 15893    2017-12-31 21:54:12.0000
# 15894    2017-12-31 22:10:18.0000
# 15895    2017-12-31 22:55:10.0000
# 15896    2017-12-31 23:20:54.0000
# 15897    2017-12-31 23:33:55.0000
# Name: starttime, Length: 275196, dtype: object>

# %%
citibike_2017_data['starttime_new'] = citibike_2017_data['starttime'].astype(str) + '.0000'
citibike_2017_data['stoptime_new'] = citibike_2017_data['stoptime'].astype(str) + '.0000'

# %%
citibike_2017_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1          1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2           372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3          1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4           639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id     end station name  end station latitude  \
# ...

# %%
citibike_2017_data.drop(columns=['starttime','stoptime'], inplace=True)
citibike_2017_data.head()
# Out:
#    tripduration  start station id start station name  start station latitude  \
# 0           148              3276   Marin Light Rail               40.714584
# 1          1283              3183     Exchange Place               40.716247
# 2           372              3183     Exchange Place               40.716247
# 3          1513              3194    McGinley Square               40.725340
# 4           639              3183     Exchange Place               40.716247
#
#    start station longitude  end station id     end station name  \
# 0               -74.042817            3185            City Hall
# 1               -74.033459            3198     Heights Elevator
# 2               -74.033459            3211           Newark Ave
# 3               -74.067622            3271  Danforth Light Rail
# 4               -74.033459            3203        Hamilton Park
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
citibike_2017_data.rename(columns= {'starttime_new' : 'starttime', 'stoptime_new' : 'stoptime'})
# Out:
#        tripduration  start station id start station name  \
# 0               148              3276   Marin Light Rail
# 1              1283              3183     Exchange Place
# 2               372              3183     Exchange Place
# 3              1513              3194    McGinley Square
# 4               639              3183     Exchange Place
# ...             ...               ...                ...
# 15893           972              3191           Union St
# 15894           382              3280        Astor Place
# 15895            93              3186      Grove St PATH
# 15896           186              3270    Jersey & 6th St
# 15897           422              3195            Sip Ave
#
#        start station latitude  start station longitude  end station id  \
# 0                   40.714584               -74.042817            3185
# 1                   40.716247               -74.033459            3198
# ...

# %%
citibike_201701_data.drop(columns=['starttime', 'stoptime'], inplace=True)

# %%
citibike_201701_data.head()
# Out:
#    tripduration  start station id start station name  start station latitude  \
# 0           148              3276   Marin Light Rail               40.714584
# 1          1283              3183     Exchange Place               40.716247
# 2           372              3183     Exchange Place               40.716247
# 3          1513              3194    McGinley Square               40.725340
# 4           639              3183     Exchange Place               40.716247
#
#    start station longitude  end station id     end station name  \
# 0               -74.042817            3185            City Hall
# 1               -74.033459            3198     Heights Elevator
# 2               -74.033459            3211           Newark Ave
# 3               -74.067622            3271  Danforth Light Rail
# 4               -74.033459            3203        Hamilton Park
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
citibike_201701_data.rename(columns= {'starttime_new' : 'starttime', 'stoptime_new' : 'stoptime'}, inplace=True)

# %%
citibike_201701_data.head()
# Out:
#    tripduration  start station id start station name  start station latitude  \
# 0           148              3276   Marin Light Rail               40.714584
# 1          1283              3183     Exchange Place               40.716247
# 2           372              3183     Exchange Place               40.716247
# 3          1513              3194    McGinley Square               40.725340
# 4           639              3183     Exchange Place               40.716247
#
#    start station longitude  end station id     end station name  \
# 0               -74.042817            3185            City Hall
# 1               -74.033459            3198     Heights Elevator
# 2               -74.033459            3211           Newark Ave
# 3               -74.067622            3271  Danforth Light Rail
# 4               -74.033459            3203        Hamilton Park
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
cols = list(citibike_2017_data.columns.values)

# %%
cols
# Out:
# ['tripduration',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender',
#  'starttime_new',
#  'stoptime_new']

# %%
citibike_2017_data = citibike_2017_data[['tripduration', 'starttime_new', 'stoptime_new',
 'start station id',
 'start station name',
 'start station latitude',
 'start station longitude',
 'end station id',
 'end station name',
 'end station latitude',
 'end station longitude',
 'bikeid',
 'usertype',
 'birth year',
 'gender']]

# %%
citibike_2017_data.head()
# Out:
#    tripduration             starttime_new              stoptime_new  \
# 0           148  2017-01-01 00:21:32.0000  2017-01-01 00:24:01.0000
# 1          1283  2017-01-01 00:24:35.0000  2017-01-01 00:45:58.0000
# 2           372  2017-01-01 00:38:19.0000  2017-01-01 00:44:31.0000
# 3          1513  2017-01-01 00:38:37.0000  2017-01-01 01:03:50.0000
# 4           639  2017-01-01 01:47:52.0000  2017-01-01 01:58:31.0000
#
#    start station id start station name  start station latitude  \
# 0              3276   Marin Light Rail               40.714584
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3194    McGinley Square               40.725340
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id     end station name  \
# 0               -74.042817            3185            City Hall
# ...

# %%
citibike_201702_data['starttime_new'] = citibike_201702_data['starttime'].astype(str) + '.0000'
citibike_201702_data['stoptime_new'] = citibike_201702_data['stoptime'].astype(str) + '.0000'
citibike_201702_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           435  2017-02-01 00:06:33  2017-02-01 00:13:49              3214
# 1           779  2017-02-01 01:02:21  2017-02-01 01:15:21              3194
# 2           145  2017-02-01 01:56:05  2017-02-01 01:58:30              3211
# 3           184  2017-02-01 04:38:42  2017-02-01 04:41:46              3276
# 4           197  2017-02-01 04:42:22  2017-02-01 04:45:39              3214
#
#   start station name  start station latitude  start station longitude  \
# 0   Essex Light Rail               40.712774               -74.036486
# 1    McGinley Square               40.725340               -74.067622
# 2         Newark Ave               40.721525               -74.046305
# 3   Marin Light Rail               40.714584               -74.042817
# 4   Essex Light Rail               40.712774               -74.036486
#
#    end station id      end station name  end station latitude  \
# ...

# %%
citibike_201701_data.drop(columns=['starttime', 'stoptime'], inplace=True)

# %%
citibike_2017_data.rename(columns= {'starttime_new' : 'starttime', 'stoptime_new' : 'stoptime'}, inplace=True)
citibike_2017_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           148  2017-01-01 00:21:32.0000  2017-01-01 00:24:01.0000
# 1          1283  2017-01-01 00:24:35.0000  2017-01-01 00:45:58.0000
# 2           372  2017-01-01 00:38:19.0000  2017-01-01 00:44:31.0000
# 3          1513  2017-01-01 00:38:37.0000  2017-01-01 01:03:50.0000
# 4           639  2017-01-01 01:47:52.0000  2017-01-01 01:58:31.0000
#
#    start station id start station name  start station latitude  \
# 0              3276   Marin Light Rail               40.714584
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3194    McGinley Square               40.725340
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id     end station name  \
# 0               -74.042817            3185            City Hall
# ...

# %%
citibike_2017_data['tripduration'].astype
# Out:
# <bound method NDFrame.astype of 0         148
# 1        1283
# 2         372
# 3        1513
# 4         639
#          ...
# 15893     972
# 15894     382
# 15895      93
# 15896     186
# 15897     422
# Name: tripduration, Length: 275196, dtype: int64>

# %%
citibike_2017_data.to_csv("citibike_2017.csv", index=False)
